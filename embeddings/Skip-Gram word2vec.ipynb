# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like translations.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with language and words, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter
import random

t = 1e-5
word_counts = Counter(int_words)
total_counts = len(int_words)
drop_prob = {word: 1 - np.sqrt(t / (count / total_counts)) for word, count in word_counts.items()}

# %%
## Your code here
train_words = [word for word in int_words if drop_prob[word] < random.random()]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
set(int_words[0:2] + int_words[3:5])
# Out:
# {5, 194, 3083, 5239}

# %%
int_words[0:2] + int_words[3:5]
# Out:
# [5239, 3083, 5, 194]

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    R = np.random.randint(1, window_size + 1)
    start_idx = idx - R if (idx - R) > 0 else 0
    end_idx = idx + R
    
    return words[start_idx:idx] + words[idx:end_idx]

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From Chris McCormick's blog, we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as one-hot encoded vectors. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. This weight matrix is usually called the embedding matrix or embedding look-up table. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None])
    labels = tf.placeholder(tf.int32, [None, 1])

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of neurons in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using one-hot encoded vectors for our inputs. When you do the matrix multiplication of the one-hot vector with the embedding matrix, you end up selecting only one row out of the entire matrix:
#
# ![one-hot matrix multiplication](assets/matrix_mult_w_one_hot.png)
#
# You don't actually need to do the matrix multiplication, you just need to select the row in the embedding matrix that corresponds to the input word. Then, the embedding matrix becomes a lookup table, you're looking up a vector the size of the hidden layer that represents the input word.
#
# <img src="assets/word2vec_weight_matrix_lookup_table.png" width=500>
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform). This [TensorFlow tutorial](https://www.tensorflow.org/tutorials/word2vec) will help if you get stuck.

# %%
n_vocab = len(int_to_vocab)
n_embedding =  200
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform([n_vocab, n_embedding], -1, 1))
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev = 1.0 / np.sqrt(n_embedding)))
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# mkdir: checkpoints: File exists

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.4808 0.3511 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.3692 0.3491 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.1569 0.3371 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.1870 0.3291 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.0777 0.3272 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.0623 0.3290 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.0699 0.3322 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.0405 0.3315 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 4.9424 0.3276 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 4.9164 0.3275 sec/batch
# Nearest to and: jumbled, bogside, fugitive, bitterly, tax, employees, emerson, kebir,
# Nearest to history: grapevines, invoke, rourke, dire, vincennes, xo, nmda, gong,
# Nearest to after: parked, tallapoosa, dependencies, fictive, antonine, hle, spouses, bain,
# Nearest to some: skeptic, daniele, icrm, corrected, sarcastic, ignatius, closures, gauze,
# Nearest to state: thracian, nomen, maitre, ascendant, appropriation, islamabad, gino, googolplex,
# Nearest to th: round, bede, ediacara, venosus, corus, laredo, mush, manicheanism,
# Nearest to six: flavours, count, abbreviating, incoming, flavio, gorillaz, herat, lazare,
# Nearest to were: enoch, navy, allein, mimi, lazy, unbound, fail, stfm,
# Nearest to primarily: range, ller, accepted, the, kitsch, interconnected, goebel, sequence,
# Nearest to universe: puppy, suspicions, knapsack, copyrights, tilting, disenfranchised, deinstitutionalization, phthalocyanine,
# Nearest to joseph: desiring, tolbert, curls, amputees, bitmaps, qur, mussolini, nagako,
# Nearest to assembly: qarase, graduates, track, indeterminacy, men, pont, alastair, graze,
# Nearest to troops: guybrush, yasukuni, rattus, ritual, cerebrospinal, rang, driving, memoirs,
# Nearest to channel: jaroslav, figaro, sometime, apologetics, margarine, holiday, morrie, drive,
# Nearest to grand: ide, grossed, integrating, strenuous, gurion, geronimo, circumcisions, absorptive,
# Nearest to engineering: als, scudo, shou, kekul, hokkaido, fb, flee, championships,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 4.9634 0.3297 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 4.8630 0.3261 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 4.7903 0.3296 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 4.7278 0.3275 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 4.6752 0.3305 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 4.6732 0.3275 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 4.6254 0.3297 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 4.5663 0.3272 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 4.5394 0.3261 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.5376 0.3251 sec/batch
# Nearest to and: employees, correspondence, jumbled, bogside, tax, absorbed, bitterly, fugitive,
# Nearest to history: invoke, grapevines, corporate, rourke, vhs, patents, gramophone, sight,
# Nearest to after: dependencies, parked, unknown, bain, fictive, cts, tallapoosa, jeff,
# Nearest to some: skeptic, corrected, constitute, daniele, closures, equated, there, sarcastic,
# Nearest to state: thracian, slightly, nomen, application, twelfth, ascendant, respect, googolplex,
# Nearest to th: round, bede, incarnation, story, new, situations, ediacara, venosus,
# Nearest to six: flavours, count, incoming, abbreviating, tighten, passionately, lazare, enchantments,
# Nearest to were: enoch, navy, fail, dating, quest, mimi, lazy, colorado,
# Nearest to primarily: range, accepted, ller, sequence, criticized, office, sighted, kitsch,
# Nearest to universe: puppy, suspicions, copyrights, representation, claim, tilting, majorities, credible,
# Nearest to joseph: desiring, curls, qur, bitmaps, once, mussolini, tolbert, amputees,
# Nearest to assembly: track, men, qarase, graduates, applied, alastair, pont, twice,
# Nearest to troops: guybrush, ritual, yasukuni, driving, memoirs, education, src, arranging,
# Nearest to channel: jaroslav, holiday, drive, sometime, figaro, apologetics, guitar, soderbergh,
# Nearest to grand: ide, integrating, grossed, strenuous, gurion, circumcisions, ille, absorptive,
# Nearest to engineering: als, scudo, fb, flee, shou, championships, kekul, kenneth,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.4882 0.3308 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.4425 0.3269 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.4341 0.3260 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.4215 0.3127 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.3676 0.3106 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.3951 0.3098 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.3347 0.3110 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.3853 0.3098 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.3762 0.3092 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.3789 0.3100 sec/batch
# Nearest to and: jumbled, bitterly, fugitive, interred, employees, correspondence, tax, kebir,
# Nearest to history: grapevines, invoke, rourke, vincennes, policymakers, dire, gong, gramophone,
# Nearest to after: unknown, fictive, dependencies, bain, parked, physicist, jeff, spouses,
# Nearest to some: skeptic, constitute, corrected, ignatius, closures, equated, daniele, sarcastic,
# Nearest to state: nomen, thracian, slightly, islamabad, twelfth, appropriation, ascendant, googolplex,
# Nearest to th: round, bede, venosus, incarnation, corus, ediacara, wallis, situations,
# Nearest to six: flavours, count, abbreviating, incoming, obey, vadis, cecil, overhauling,
# Nearest to were: enoch, navy, quest, fail, dating, unbound, provincial, colorado,
# Nearest to primarily: ller, accepted, range, criticized, sequence, kitsch, justifiably, federations,
# Nearest to universe: puppy, suspicions, copyrights, millennia, representation, claim, radios, majorities,
# Nearest to joseph: mussolini, desiring, qur, curls, bitmaps, amputees, tolbert, once,
# Nearest to assembly: track, graduates, men, pont, qarase, twice, alastair, applied,
# Nearest to troops: guybrush, ritual, yasukuni, memoirs, tourism, provoked, driving, education,
# Nearest to channel: jaroslav, sometime, holiday, drive, figaro, apologetics, guitar, soderbergh,
# Nearest to grand: grossed, integrating, ide, strenuous, gurion, ille, circumcisions, eight,
# Nearest to engineering: als, fb, championships, scudo, flee, tariffs, shou, kenneth,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.3812 0.3138 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.3609 0.3121 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.3046 0.3136 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.2822 0.3147 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.3776 0.3103 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.3102 0.3176 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.3028 0.3171 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.3047 0.3178 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.2834 0.3197 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.2442 0.3197 sec/batch
# Nearest to and: jumbled, bitterly, fugitive, byproduct, thames, interred, aeg, correspondence,
# Nearest to history: grapevines, rourke, dire, vincennes, malaysian, invoke, policymakers, appreciating,
# Nearest to after: fictive, bain, dependencies, cts, unknown, watercolors, emails, physicist,
# Nearest to some: constitute, equated, ignatius, skeptic, closures, corrected, gauze, wavelet,
# Nearest to state: nomen, appropriation, pretended, fundraising, thracian, islamabad, ascendant, googolplex,
# Nearest to th: round, venosus, bede, incarnation, rants, ediacara, corus, wallis,
# Nearest to six: flavours, count, cecil, murdoch, interdependence, vadis, okinawa, flavio,
# Nearest to were: enoch, navy, provincial, unbound, quest, dating, colorado, fail,
# Nearest to primarily: ller, accepted, criticized, range, sequence, justifiably, susceptibility, federations,
# Nearest to universe: puppy, copyrights, suspicions, millennia, claim, radios, causeway, representation,
# Nearest to joseph: mussolini, desiring, chemin, fretting, curls, tolbert, flaubert, wilhelm,
# Nearest to assembly: track, pont, graduates, men, northerner, qarase, twice, alastair,
# Nearest to troops: yasukuni, provoked, guybrush, renounce, tourism, src, motorists, memoirs,
# Nearest to channel: jaroslav, sometime, soderbergh, figaro, holiday, apologetics, margarine, easing,
# Nearest to grand: grossed, gurion, strenuous, ide, integrating, eight, ille, earls,
# Nearest to engineering: als, fb, scudo, championships, shou, tariffs, grasses, flee,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.2667 0.3199 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.2632 0.3205 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.2129 0.3243 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.2316 0.3176 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.2279 0.3094 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.2245 0.3096 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.2141 0.2278 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.1659 0.3091 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.1561 0.3092 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.1194 0.3089 sec/batch
# Nearest to and: jumbled, bitterly, aeg, fugitive, kebir, opentype, correspondence, ukrainians,
# Nearest to history: grapevines, malaysian, policymakers, rourke, dire, vincennes, xo, gramophone,
# Nearest to after: fictive, bain, tallapoosa, watercolors, unknown, disappointing, cts, emails,
# Nearest to some: equated, constitute, closures, skeptic, ignatius, corrected, wavelet, lycaon,
# Nearest to state: nomen, pretended, fundraising, appropriation, ascendant, thracian, mongols, twelfth,
# Nearest to th: round, bede, venosus, ediacara, rants, incarnation, corus, kagoshima,
# Nearest to six: count, flavours, cecil, murdoch, one, sculptor, interdependence, vadis,
# Nearest to were: enoch, navy, quest, unbound, provincial, dating, allein, colorado,
# Nearest to primarily: ller, range, accepted, sequence, criticized, justifiably, federations, susceptibility,
# Nearest to universe: puppy, copyrights, knapsack, suspicions, claim, millennia, credible, representation,
# Nearest to joseph: mussolini, desiring, chemin, wilhelm, curls, fretting, flaubert, amputees,
# Nearest to assembly: pont, track, northerner, subunits, bipartite, graduates, lh, twice,
# Nearest to troops: provoked, guybrush, renounce, yasukuni, gon, tourism, dawson, longitude,
# Nearest to channel: jaroslav, soderbergh, sometime, figaro, margarine, holiday, drive, easing,
# Nearest to grand: grossed, eight, gurion, strenuous, ide, earls, ille, beazley,
# Nearest to engineering: als, fb, scudo, championships, shou, decay, benzene, intel,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.1162 0.3134 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.1146 0.3081 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.0932 0.3101 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.1308 0.3112 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.0865 0.3089 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.0939 0.3092 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.0678 0.3083 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.0050 0.3091 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.0422 0.3102 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.0157 0.3109 sec/batch
# Nearest to and: jumbled, aeg, bitterly, byproduct, make, kebir, ukrainians, geoffroy,
# Nearest to history: grapevines, malaysian, corporate, policymakers, vincennes, rourke, professor, gramophone,
# Nearest to after: fictive, tallapoosa, bain, shut, would, cts, disappointing, unknown,
# Nearest to some: equated, constitute, closures, corrected, ignatius, skeptic, roundup, lycaon,
# Nearest to state: pretended, nomen, fundraising, mongols, appropriation, southerner, prosperity, ascendant,
# Nearest to th: round, bede, venosus, corus, ediacara, incarnation, sergeant, kagoshima,
# Nearest to six: flavours, count, murdoch, cecil, interdependence, flavio, gorillaz, overhauling,
# Nearest to were: enoch, navy, unbound, quest, provincial, allein, dating, rer,
# Nearest to primarily: ller, range, sequence, accepted, criticized, federations, susceptibility, estaing,
# Nearest to universe: puppy, copyrights, millennia, knapsack, suspicions, representation, tilting, credible,
# Nearest to joseph: mussolini, desiring, wilhelm, curls, chemin, amputees, flaubert, fretting,
# Nearest to assembly: pont, northerner, niemeyer, track, bipartite, subunits, president, azathoth,
# Nearest to troops: provoked, renounce, guybrush, yasukuni, travelled, gon, consolidated, longitude,
# Nearest to channel: jaroslav, soderbergh, figaro, sometime, easing, abijah, drive, margarine,
# Nearest to grand: grossed, eight, gurion, strenuous, beazley, andrea, percentage, ille,
# Nearest to engineering: als, fb, scudo, benzene, decay, championships, beeb, shou,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.0512 0.3132 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.0393 0.3086 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.0430 0.3105 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.0120 0.3111 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.0122 0.3099 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.0661 0.3102 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.0140 0.3112 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 3.9819 0.3102 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.0284 0.3090 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 3.9951 0.3098 sec/batch
# Nearest to and: aeg, jumbled, kebir, geoffroy, ukrainians, byproduct, opentype, fugitive,
# Nearest to history: grapevines, malaysian, corporate, professor, rourke, xo, policymakers, ramparts,
# Nearest to after: fictive, tallapoosa, shut, hle, bain, disappointing, would, antonine,
# Nearest to some: constitute, equated, corrected, skeptic, closures, adaptions, roundup, lycaon,
# Nearest to state: pretended, nomen, appropriation, fundraising, islamabad, ascendant, mongols, southerner,
# Nearest to th: round, bede, venosus, ediacara, century, kagoshima, corus, visigoths,
# Nearest to six: count, cecil, flavours, murdoch, flavio, gorillaz, one, interdependence,
# Nearest to were: enoch, navy, dating, unbound, quest, allein, howie, rer,
# Nearest to primarily: range, criticized, estaing, accepted, federations, ller, minimise, derail,
# Nearest to universe: puppy, millennia, knapsack, copyrights, suspicions, credible, tilting, claim,
# Nearest to joseph: mussolini, wilhelm, desiring, chemin, tolbert, amputees, flaubert, fretting,
# Nearest to assembly: pont, president, northerner, subunits, niemeyer, bipartite, legislative, azathoth,
# Nearest to troops: renounce, provoked, guybrush, gon, consolidated, travelled, rossa, yasukuni,
# Nearest to channel: jaroslav, soderbergh, figaro, drive, abijah, sometime, easing, margarine,
# Nearest to grand: grossed, strenuous, gurion, eight, beazley, marginally, bellamy, ille,
# Nearest to engineering: fb, als, benzene, scudo, decay, championships, manufacturers, intel,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 3.9732 0.3129 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.0276 0.3090 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 3.9990 0.3102 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 3.9541 0.3095 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.0168 0.3093 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 3.9825 0.3107 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.0261 0.3106 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 3.9953 0.3096 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 3.9536 0.3108 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 3.9479 0.3087 sec/batch
# Nearest to and: aeg, jumbled, kebir, ukrainians, geoffroy, elbridge, evaluator, bitterly,
# Nearest to history: grapevines, malaysian, professor, corporate, xo, gong, policymakers, ramparts,
# Nearest to after: fictive, tallapoosa, shut, antonine, hle, bain, watercolors, would,
# Nearest to some: equated, constitute, adaptions, closures, skeptic, corrected, roundup, gauze,
# Nearest to state: nomen, appropriation, pretended, southerner, prosperity, islamabad, inventors, mongols,
# Nearest to th: round, bede, century, venosus, ediacara, visigoths, corus, mascheroni,
# Nearest to six: count, ede, flavio, stratovolcano, flavours, cruzeiro, one, five,
# Nearest to were: enoch, navy, allein, dating, provincial, emmerdale, dismantling, quest,
# Nearest to primarily: estaing, microprogramming, range, visualizing, palomino, minimise, ller, derail,
# Nearest to universe: puppy, copyrights, millennia, spinoza, knapsack, suspicions, tilting, credible,
# Nearest to joseph: mussolini, wilhelm, chemin, amputees, desiring, flaubert, fretting, channing,
# Nearest to assembly: pont, northerner, president, legislative, parliaments, niemeyer, subunits, bipartite,
# Nearest to troops: renounce, provoked, rossa, consolidated, gon, travelled, guybrush, cession,
# Nearest to channel: jaroslav, soderbergh, drive, abijah, figaro, easing, librarianship, margarine,
# Nearest to grand: grossed, strenuous, all, gurion, earls, eight, marginally, beazley,
# Nearest to engineering: fb, als, benzene, scudo, decay, manufacturers, intel, championships,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 3.9667 0.3135 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 3.9198 0.3114 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.0193 0.3094 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 3.9936 0.3094 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 3.9851 0.3088 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 3.9060 0.3092 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 3.8842 0.3080 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 3.9626 0.3099 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 3.8526 0.3097 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 3.8953 0.3089 sec/batch
# Nearest to and: aeg, ukrainians, jumbled, geoffroy, kebir, evaluator, elbridge, opentype,
# Nearest to history: grapevines, malaysian, professor, xo, gong, krzy, policymakers, corporate,
# Nearest to after: fictive, hle, shut, tallapoosa, antonine, disappointing, kinetoscope, parked,
# Nearest to some: equated, constitute, adaptions, corrected, skeptic, closures, presentations, gauze,
# Nearest to state: pretended, nomen, appropriation, southerner, inventors, mongols, prosperity, fundraising,
# Nearest to th: round, bede, century, venosus, ediacara, visigoths, corus, origins,
# Nearest to six: count, sculptor, stratovolcano, five, ede, flavio, cecil, cruzeiro,
# Nearest to were: enoch, navy, allein, emmerdale, dating, dismantling, covertly, provincial,
# Nearest to primarily: microprogramming, estaing, range, derail, beacons, palomino, criticized, visualizing,
# Nearest to universe: puppy, spinoza, knapsack, millennia, copyrights, philosophers, vivre, suspicions,
# Nearest to joseph: wilhelm, mussolini, chemin, channing, desiring, tolbert, flaubert, keller,
# Nearest to assembly: pont, northerner, legislative, parliaments, president, subunits, bicameral, duval,
# Nearest to troops: renounce, provoked, rossa, consolidated, compatriots, cession, ii, travelled,
# Nearest to channel: jaroslav, soderbergh, drive, tv, librarianship, abijah, multicast, figaro,
# Nearest to grand: grossed, gurion, earls, all, bellamy, montenegrins, eight, strenuous,
# Nearest to engineering: als, benzene, fb, scudo, digitization, manufacturers, shou, beeb,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 3.9328 0.3127 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 3.9043 0.3099 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 3.9683 0.1429 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 3.9143 0.3107 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 3.8542 0.3105 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 3.8803 0.3099 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 3.8435 0.3083 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 3.8170 0.3086 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 3.8404 0.3120 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 3.8179 0.3113 sec/batch
# Nearest to and: aeg, ukrainians, kebir, geoffroy, jumbled, superhighway, terrible, opentype,
# Nearest to history: grapevines, malaysian, xo, krzy, professor, gong, auckland, gramophone,
# Nearest to after: fictive, hle, shut, tallapoosa, antonine, disappointing, motorsports, kinetoscope,
# Nearest to some: equated, constitute, corrected, adaptions, roundup, skeptic, closures, rosh,
# Nearest to state: southerner, nomen, inventors, appropriation, pretended, fundraising, islamabad, prosperity,
# Nearest to th: century, bede, round, venosus, visigoths, ediacara, origins, corus,
# Nearest to six: count, stratovolcano, ede, sculptor, flavio, gorillaz, cruzeiro, models,
# Nearest to were: enoch, navy, allein, emmerdale, dismantling, quest, dating, covertly,
# Nearest to primarily: microprogramming, range, palomino, estaing, substituent, beacons, visualizing, susceptibility,
# Nearest to universe: puppy, spinoza, knapsack, copyrights, millennia, griechische, philosophers, credible,
# Nearest to joseph: mussolini, wilhelm, desiring, chemin, keller, flaubert, tolbert, channing,
# Nearest to assembly: northerner, legislative, pont, parliaments, bicameral, subunits, niemeyer, bipartite,
# Nearest to troops: renounce, rossa, travelled, nkvd, provoked, gon, consolidated, compatriots,
# Nearest to channel: jaroslav, soderbergh, drive, tv, librarianship, figaro, multicast, abijah,
# Nearest to grand: grossed, all, prix, strenuous, bellamy, gurion, plantagenet, guts,
# Nearest to engineering: als, benzene, fb, scudo, digitization, decay, beeb, shou,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 3.8668 0.3131 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 3.8465 0.3121 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 3.8435 0.3097 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 3.7697 0.3114 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 3.7999 0.3090 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 3.7959 0.3101 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 3.7821 0.3092 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 3.8133 0.3102 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 3.8344 0.3090 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 3.8084 0.3100 sec/batch
# Nearest to and: aeg, kebir, ukrainians, superhighway, geoffroy, jumbled, equites, terrible,
# Nearest to history: grapevines, malaysian, gong, xo, thule, appreciating, krzy, auckland,
# Nearest to after: fictive, shut, hle, tallapoosa, antonine, pistons, disappointing, malleson,
# Nearest to some: equated, corrected, constitute, roundup, adaptions, skeptic, presentations, rosh,
# Nearest to state: appropriation, nomen, southerner, inventors, pretended, biotechnology, fundraising, provisions,
# Nearest to th: century, bede, round, venosus, ediacara, corus, origins, mascheroni,
# Nearest to six: count, stratovolcano, ede, cruzeiro, gorillaz, sculptor, flavio, five,
# Nearest to were: enoch, navy, allein, dismantling, emmerdale, quest, tonkin, helmuth,
# Nearest to primarily: microprogramming, palomino, substituent, estaing, susceptibility, beacons, minimise, derail,
# Nearest to universe: puppy, spinoza, knapsack, millennia, copyrights, griechische, philosophers, bang,
# Nearest to joseph: mussolini, wilhelm, tolbert, desiring, chemin, judeo, flaubert, qur,
# Nearest to assembly: northerner, legislative, parliaments, pont, bicameral, niemeyer, duval, subunits,
# Nearest to troops: renounce, rossa, travelled, consolidated, nkvd, compatriots, brigades, forces,
# Nearest to channel: jaroslav, tv, soderbergh, drive, librarianship, figaro, abijah, criollo,
# Nearest to grand: grossed, all, prix, strenuous, gurion, vitebsk, farces, bellamy,
# Nearest to engineering: benzene, als, fb, digitization, scudo, beeb, research, shou,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 3.8098 0.3152 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 3.8666 0.3111 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 3.8053 0.3115 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 3.7786 0.3101 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 3.8279 0.3097 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 3.8186 0.3088 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 3.8357 0.3089 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 3.7589 0.3099 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 3.7636 0.3100 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 3.8032 0.3107 sec/batch
# Nearest to and: aeg, kebir, ukrainians, geoffroy, superhighway, cancels, opentype, equites,
# Nearest to history: grapevines, malaysian, thule, gong, appreciating, krzy, xo, gramophone,
# Nearest to after: fictive, tallapoosa, hle, shut, disappointing, antonine, malleson, kinetoscope,
# Nearest to some: equated, constitute, corrected, rosh, presentations, skeptic, devised, multisyllabic,
# Nearest to state: inventors, nomen, southerner, biotechnology, appropriation, islamabad, fundraising, provisions,
# Nearest to th: century, bede, round, ediacara, venosus, origins, corus, attested,
# Nearest to six: count, ede, stratovolcano, sculptor, cruzeiro, gorillaz, five, flavio,
# Nearest to were: emmerdale, enoch, dismantling, allein, quest, navy, dating, whampoa,
# Nearest to primarily: beacons, palomino, microprogramming, derail, susceptibility, estaing, minimise, substituent,
# Nearest to universe: spinoza, puppy, knapsack, griechische, bang, copyrights, philosophers, gravity,
# Nearest to joseph: wilhelm, mussolini, keller, tolbert, desiring, flaubert, chemin, rolland,
# Nearest to assembly: northerner, legislative, pont, bicameral, duval, niemeyer, parliaments, subunits,
# Nearest to troops: renounce, rossa, surrendered, consolidated, forces, gon, nkvd, yasukuni,
# Nearest to channel: jaroslav, tv, figaro, librarianship, criollo, abijah, soderbergh, multicast,
# Nearest to grand: grossed, all, prix, strenuous, gurion, vitebsk, farces, itv,
# Nearest to engineering: benzene, als, fb, scudo, digitization, research, beeb, shou,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 3.8178 0.3145 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 3.8223 0.3099 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 3.8058 0.3092 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 3.7835 0.3089 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 3.7773 0.3091 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 3.7661 0.3093 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 3.7865 0.3098 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 3.7804 0.3100 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 3.8489 0.3101 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 3.8439 0.3089 sec/batch
# Nearest to and: kebir, ukrainians, aeg, elbridge, terrible, geoffroy, bitterly, equites,
# Nearest to history: grapevines, malaysian, thule, krzy, appreciating, prehistory, auckland, gong,
# Nearest to after: fictive, tallapoosa, hle, antonine, shut, malleson, disappointing, unknown,
# Nearest to some: equated, rosh, constitute, devised, corrected, presentations, multisyllabic, skeptic,
# Nearest to state: inventors, southerner, nomen, appropriation, provisions, ucsd, fundraising, islamabad,
# Nearest to th: century, bede, round, ediacara, origins, venosus, attested, rd,
# Nearest to six: count, sculptor, stratovolcano, ede, five, abensberg, cruzeiro, flavio,
# Nearest to were: enoch, emmerdale, dismantling, allein, navy, quest, covertly, tonkin,
# Nearest to primarily: beacons, microprogramming, palomino, susceptibility, derail, substituent, nyu, minimise,
# Nearest to universe: spinoza, puppy, griechische, bang, copyrights, knapsack, philosophers, suspicions,
# Nearest to joseph: wilhelm, mussolini, keller, desiring, dabbled, tolbert, rolland, aloysius,
# Nearest to assembly: bicameral, northerner, legislative, pont, duval, niemeyer, parliaments, azathoth,
# Nearest to troops: rossa, renounce, ii, surrendered, forces, nkvd, consolidated, brigades,
# Nearest to channel: jaroslav, librarianship, tv, figaro, criollo, multicast, abijah, soderbergh,
# Nearest to grand: grossed, all, prix, vitebsk, farces, bellamy, tiamat, strenuous,
# Nearest to engineering: benzene, als, fb, research, encouragement, digitization, scudo, shou,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 3.8597 0.3142 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 3.7565 0.3165 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 3.7494 0.3103 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 3.7739 0.3171 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 3.6838 0.3185 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 3.7908 0.3201 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 3.7486 0.3134 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 3.7568 0.3173 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 3.8143 0.0594 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 3.7656 0.3118 sec/batch
# Nearest to and: aeg, kebir, ukrainians, geoffroy, superhighway, trident, terrible, belted,
# Nearest to history: grapevines, malaysian, krzy, thule, appreciating, prehistory, auckland, xo,
# Nearest to after: fictive, tallapoosa, hle, shut, antonine, disappointing, unknown, pistons,
# Nearest to some: equated, presentations, gauze, devised, multisyllabic, corrected, closures, adaptions,
# Nearest to state: inventors, southerner, fundraising, nomen, appropriation, provisions, ucsd, biotechnology,
# Nearest to th: century, bede, round, ediacara, origins, attested, rd, venosus,
# Nearest to six: count, ede, stratovolcano, gorillaz, sculptor, five, abensberg, cruzeiro,
# Nearest to were: emmerdale, dismantling, enoch, allein, kindia, covertly, whampoa, relies,
# Nearest to primarily: beacons, microprogramming, susceptibility, palomino, derail, nyu, renowned, range,
# Nearest to universe: spinoza, puppy, griechische, bang, knapsack, copyrights, earth, interdental,
# Nearest to joseph: wilhelm, keller, mussolini, desiring, rolland, aloysius, dabbled, tolbert,
# Nearest to assembly: bicameral, northerner, legislative, pont, duval, niemeyer, parliaments, azathoth,
# Nearest to troops: renounce, rossa, nkvd, ii, forces, consolidated, brigades, surrendered,
# Nearest to channel: jaroslav, tv, figaro, librarianship, criollo, multicast, xeric, backgrounds,
# Nearest to grand: all, grossed, prix, vitebsk, tiamat, farces, bellamy, plantagenet,
# Nearest to engineering: benzene, encouragement, digitization, fb, research, als, scudo, engineers,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 3.7022 0.3124 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 3.7075 0.3096 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 3.7314 0.3105 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 3.6657 0.3093 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 3.7024 0.3104 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 3.6622 0.3094 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 3.7175 0.3096 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 3.6866 0.3102 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 3.7837 0.3083 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 3.6629 0.3102 sec/batch
# Nearest to and: kebir, aeg, ukrainians, bitterly, terrible, superhighway, bitnet, superpower,
# Nearest to history: grapevines, prehistory, malaysian, thrilling, thule, appreciating, krzy, auckland,
# Nearest to after: fictive, tallapoosa, hle, shut, disappointing, mismatch, malleson, aiming,
# Nearest to some: equated, presentations, devised, closures, rosh, corrected, thereof, urbanisation,
# Nearest to state: inventors, nomen, southerner, appropriation, fundraising, biotechnology, ucsd, provisions,
# Nearest to th: century, round, bede, ediacara, origins, rd, defeating, attested,
# Nearest to six: count, stratovolcano, gorillaz, ede, abensberg, cruzeiro, models, sculptor,
# Nearest to were: emmerdale, dismantling, enoch, allein, navy, kindia, megabyte, relies,
# Nearest to primarily: beacons, susceptibility, microprogramming, palomino, substituent, nyu, derail, minimise,
# Nearest to universe: spinoza, bang, puppy, nucleosynthesis, knapsack, griechische, earth, big,
# Nearest to joseph: wilhelm, mussolini, desiring, keller, redactor, aloysius, dabbled, rolland,
# Nearest to assembly: bicameral, northerner, legislative, niemeyer, duval, proportional, pont, parliaments,
# Nearest to troops: rossa, renounce, nkvd, forces, ii, surrendered, brigades, consolidated,
# Nearest to channel: jaroslav, tv, criollo, figaro, librarianship, multicast, backgrounds, soderbergh,
# Nearest to grand: prix, grossed, all, farces, tiamat, plantagenet, vitebsk, itv,
# Nearest to engineering: encouragement, benzene, bioengineering, fb, digitization, macroeconomics, engineers, als,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 3.6793 0.3142 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 3.6608 0.3097 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 3.6464 0.3096 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 3.6904 0.3097 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 3.7238 0.3106 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 3.6875 0.3103 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 3.7031 0.3129 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 3.7144 0.3097 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 3.7009 0.3104 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 3.6612 0.3097 sec/batch
# Nearest to and: kebir, aeg, ukrainians, cancels, opentype, superhighway, borde, bitterly,
# Nearest to history: grapevines, thule, appreciating, thrilling, krzy, prehistory, deconstructing, auckland,
# Nearest to after: fictive, tallapoosa, hle, shut, mismatch, disappointing, knocked, pistons,
# Nearest to some: equated, thereof, presentations, corrected, cryptanalyst, gauze, devised, multisyllabic,
# Nearest to state: inventors, nomen, appropriation, biotechnology, southerner, nationalities, provisions, fundraising,
# Nearest to th: century, bede, round, ediacara, rd, origins, defeating, attested,
# Nearest to six: ede, stratovolcano, gorillaz, count, cruzeiro, five, three, abensberg,
# Nearest to were: emmerdale, enoch, dismantling, quest, relies, allein, kindia, megabyte,
# Nearest to primarily: beacons, susceptibility, nyu, palomino, mortgage, substituent, estaing, microprogramming,
# Nearest to universe: spinoza, bang, puppy, nucleosynthesis, knapsack, griechische, earth, big,
# Nearest to joseph: wilhelm, keller, dabbled, mussolini, desiring, redactor, aloysius, rolland,
# Nearest to assembly: bicameral, northerner, legislative, niemeyer, duval, subunits, pont, proportional,
# Nearest to troops: rossa, renounce, nkvd, surrendered, ii, forces, ashbury, shawar,
# Nearest to channel: jaroslav, tv, figaro, criollo, librarianship, multicast, soderbergh, stibitz,
# Nearest to grand: prix, grossed, all, farces, tiamat, vitebsk, plantagenet, marginally,
# Nearest to engineering: engineers, benzene, encouragement, digitization, macroeconomics, bioengineering, fb, research,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 3.6803 0.3133 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 3.6949 0.3083 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 3.6888 0.3098 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 3.6886 0.3093 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 3.6901 0.3104 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 3.6835 0.3100 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 3.7002 0.3101 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 3.6994 0.3102 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 3.7249 0.3111 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 3.7080 0.3095 sec/batch
# Nearest to and: kebir, aeg, ukrainians, borde, bitterly, loathing, equites, cancels,
# Nearest to history: grapevines, krzy, prehistory, thule, timeline, appreciating, malaysian, predynastic,
# Nearest to after: fictive, tallapoosa, hle, unknown, shut, malleson, mismatch, knocked,
# Nearest to some: equated, thereof, cryptanalyst, constitute, gauze, skeptic, padma, devised,
# Nearest to state: nomen, inventors, appropriation, southerner, nationalities, fundraising, biotechnology, provisions,
# Nearest to th: century, bede, round, rd, ediacara, defeating, origins, attested,
# Nearest to six: ede, count, stratovolcano, abensberg, gorillaz, cruzeiro, sculptor, five,
# Nearest to were: emmerdale, dismantling, enoch, relies, quest, allein, megabyte, whampoa,
# Nearest to primarily: beacons, susceptibility, derail, palomino, nyu, substituent, mortgage, estaing,
# Nearest to universe: spinoza, bang, puppy, griechische, nucleosynthesis, earth, big, knapsack,
# Nearest to joseph: keller, wilhelm, aloysius, redactor, dabbled, mussolini, desiring, rolland,
# Nearest to assembly: bicameral, legislative, niemeyer, northerner, proportional, duval, subunits, pont,
# Nearest to troops: renounce, rossa, nkvd, ashbury, ii, surrendered, forces, pforzheim,
# Nearest to channel: jaroslav, tv, criollo, figaro, librarianship, multicast, stibitz, backgrounds,
# Nearest to grand: prix, all, grossed, farces, tiamat, vitebsk, plantagenet, practising,
# Nearest to engineering: encouragement, benzene, macroeconomics, bioengineering, engineers, fb, digitization, als,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 3.6949 0.3140 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 3.6306 0.3081 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 3.6730 0.3103 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 3.7138 0.3090 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 3.7144 0.3091 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 3.7394 0.3095 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 3.7536 0.3108 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 3.6725 0.3099 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 3.6480 0.3106 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 3.6696 0.3083 sec/batch
# Nearest to and: kebir, aeg, ukrainians, borde, bitterly, cancels, loathing, bitnet,
# Nearest to history: grapevines, appreciating, timeline, krzy, thule, prehistory, auckland, malaysian,
# Nearest to after: fictive, tallapoosa, hle, mismatch, shut, unknown, knocked, malleson,
# Nearest to some: presentations, gauze, equated, rosh, multisyllabic, thereof, skeptic, maru,
# Nearest to state: nomen, inventors, appropriation, fundraising, nationalities, southerner, pretended, ucsd,
# Nearest to th: century, round, bede, rd, ediacara, defeating, incarnation, miura,
# Nearest to six: ede, stratovolcano, abensberg, cruzeiro, gorillaz, count, five, sculptor,
# Nearest to were: emmerdale, dismantling, enoch, relies, megabyte, allein, robles, relic,
# Nearest to primarily: beacons, susceptibility, palomino, derail, nyu, substituent, mortgage, minimise,
# Nearest to universe: spinoza, bang, puppy, griechische, nucleosynthesis, earth, big, knapsack,
# Nearest to joseph: keller, wilhelm, dabbled, desiring, aloysius, redactor, rolland, mussolini,
# Nearest to assembly: bicameral, legislative, niemeyer, northerner, subunits, duval, proportional, pont,
# Nearest to troops: nkvd, renounce, rossa, ashbury, forces, ii, pforzheim, convoys,
# Nearest to channel: jaroslav, criollo, tv, multicast, figaro, stibitz, librarianship, orientis,
# Nearest to grand: prix, all, farces, grossed, tiamat, vitebsk, plantagenet, practising,
# Nearest to engineering: encouragement, benzene, bioengineering, macroeconomics, fb, digitization, engineers, kenneth,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.6264 0.3133 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 3.6525 0.3098 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 3.6710 0.3082 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 3.6340 0.3095 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 3.7139 0.3088 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 3.6934 0.2843 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 3.6424 0.3106 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.6372 0.3121 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 3.6370 0.3091 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.5991 0.3091 sec/batch
# Nearest to and: kebir, aeg, ukrainians, loathing, bitterly, varnothing, superpower, borde,
# Nearest to history: grapevines, appreciating, timeline, thrilling, krzy, auckland, prehistory, thule,
# Nearest to after: fictive, tallapoosa, hle, shut, mismatch, unknown, motorsports, knocked,
# Nearest to some: equated, thereof, skeptic, presentations, rosh, corrected, maru, gauze,
# Nearest to state: nomen, inventors, appropriation, fundraising, southerner, nationalities, biotechnology, pretended,
# Nearest to th: century, round, bede, rd, incarnation, ediacara, nd, attested,
# Nearest to six: ede, abensberg, stratovolcano, count, five, gorillaz, sculptor, three,
# Nearest to were: emmerdale, dismantling, relic, enoch, relies, allein, megabyte, quest,
# Nearest to primarily: beacons, susceptibility, nyu, palomino, derail, substituent, mortgage, microprogramming,
# Nearest to universe: spinoza, bang, puppy, griechische, nucleosynthesis, big, earth, interdental,
# Nearest to joseph: wilhelm, keller, dabbled, aloysius, desiring, mussolini, redactor, rolland,
# Nearest to assembly: bicameral, niemeyer, duval, legislative, northerner, subunits, proportional, pont,
# Nearest to troops: nkvd, rossa, renounce, shawar, ashbury, forces, convoys, pforzheim,
# Nearest to channel: jaroslav, tv, criollo, multicast, figaro, stibitz, librarianship, orientis,
# Nearest to grand: prix, all, farces, tiamat, grossed, vitebsk, plantagenet, practising,
# Nearest to engineering: encouragement, bioengineering, engineers, benzene, digitization, fb, macroeconomics, kenneth,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.6240 0.3179 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.5783 0.3096 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 3.6405 0.3087 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 3.6546 0.3094 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 3.6549 0.3089 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.6470 0.3091 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.5700 0.3099 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.5974 0.3108 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.5389 0.3164 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.6026 0.3096 sec/batch
# Nearest to and: kebir, bitterly, loathing, varnothing, borde, aeg, superpower, ukrainians,
# Nearest to history: grapevines, thrilling, timeline, appreciating, prehistory, auckland, predynastic, krzy,
# Nearest to after: fictive, tallapoosa, hle, mismatch, shut, unknown, knocked, tarentum,
# Nearest to some: equated, thereof, corrected, maru, gauze, presentations, ghanaians, multisyllabic,
# Nearest to state: inventors, nomen, fundraising, appropriation, nationalities, oglethorpe, pretended, southerner,
# Nearest to th: century, round, bede, incarnation, rd, defeating, ediacara, mascheroni,
# Nearest to six: stratovolcano, ede, cruzeiro, three, abensberg, five, gorillaz, offset,
# Nearest to were: emmerdale, dismantling, enoch, relic, megabyte, relies, allein, robles,
# Nearest to primarily: beacons, susceptibility, substituent, palomino, depicted, nyu, derail, choreographies,
# Nearest to universe: bang, spinoza, nucleosynthesis, griechische, acceleration, puppy, big, tractable,
# Nearest to joseph: redactor, keller, wilhelm, desiring, dabbled, mussolini, judeo, aloysius,
# Nearest to assembly: bicameral, duval, niemeyer, northerner, legislative, subunits, unwritten, proportional,
# Nearest to troops: nkvd, ashbury, shawar, renounce, rossa, forces, convoys, causa,
# Nearest to channel: tv, jaroslav, criollo, multicast, figaro, talk, librarianship, orientis,
# Nearest to grand: prix, farces, all, tiamat, grossed, vitebsk, plantagenet, runyon,
# Nearest to engineering: bioengineering, encouragement, engineers, fb, benzene, macroeconomics, building, digitization,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.6530 0.3141 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.6351 0.3091 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.5761 0.3096 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 3.6465 0.3100 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 3.6535 0.3094 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.6001 0.3108 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.6421 0.3104 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.6301 0.3099 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.6238 0.3097 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.6126 0.3094 sec/batch
# Nearest to and: kebir, borde, bitterly, aeg, elbridge, loathing, varnothing, sally,
# Nearest to history: thrilling, grapevines, timeline, appreciating, krzy, prehistory, deconstructing, submitted,
# Nearest to after: fictive, tallapoosa, hle, mismatch, knocked, unknown, shut, malleson,
# Nearest to some: thereof, presentations, corrected, equated, rosh, ghanaians, gauze, skeptic,
# Nearest to state: nomen, inventors, fundraising, nationalities, application, pretended, appropriation, southerner,
# Nearest to th: century, round, bede, rd, defeating, incarnation, ediacara, nd,
# Nearest to six: ede, five, abensberg, three, cruzeiro, stratovolcano, sculptor, gorillaz,
# Nearest to were: emmerdale, dismantling, megabyte, relies, relic, enoch, quest, robles,
# Nearest to primarily: beacons, nyu, susceptibility, palomino, depicted, substituent, mortgage, choreographies,
# Nearest to universe: bang, spinoza, nucleosynthesis, griechische, big, puppy, acceleration, earth,
# Nearest to joseph: wilhelm, keller, aloysius, dabbled, desiring, philosophiques, rolland, mussolini,
# Nearest to assembly: bicameral, duval, niemeyer, northerner, legislative, subunits, proportional, majilis,
# Nearest to troops: nkvd, ashbury, renounce, shawar, causa, rossa, convoys, surrendered,
# Nearest to channel: tv, jaroslav, criollo, figaro, multicast, librarianship, talk, orientis,
# Nearest to grand: prix, all, farces, grossed, tiamat, vitebsk, kew, plantagenet,
# Nearest to engineering: bioengineering, engineers, encouragement, digitization, fb, benzene, macroeconomics, kenneth,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 3.6327 0.3150 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.6051 0.3099 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.5804 0.3091 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 3.6280 0.3100 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 3.6514 0.3106 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 3.6395 0.3105 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.6162 0.3107 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.5927 0.3078 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.5797 0.3099 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 3.6829 0.3094 sec/batch
# Nearest to and: kebir, borde, loathing, varnothing, bitterly, elbridge, sally, ukrainians,
# Nearest to history: grapevines, timeline, thrilling, prehistory, krzy, appreciating, islamic, predynastic,
# Nearest to after: fictive, tallapoosa, hle, mismatch, unknown, shut, tarentum, motorsports,
# ...
# Nearest to joseph: keller, wilhelm, redactor, recreating, philosophiques, ragnar, triadic, pardey,
# Nearest to assembly: majilis, niemeyer, subunits, emissaries, duval, legislative, deputies, bicameral,
# Nearest to troops: causa, federals, surrendered, refinery, memoirs, kuroda, ashbury, shawar,
# Nearest to channel: librarianship, criollo, fox, orientis, airing, multicast, aegeus, tv,
# Nearest to grand: prix, farces, tiamat, all, vitebsk, guts, italiani, auto,
# Nearest to engineering: bioengineering, engineers, building, introduced, transplantation, disciplines, mechanical, traitorous,
# Epoch 8/10 Iteration: 36100 Avg. Training loss: 3.5871 0.3128 sec/batch
# Epoch 8/10 Iteration: 36200 Avg. Training loss: 3.5402 0.3109 sec/batch
# Epoch 8/10 Iteration: 36300 Avg. Training loss: 3.5318 0.3095 sec/batch
# Epoch 8/10 Iteration: 36400 Avg. Training loss: 3.4692 0.3085 sec/batch
# Epoch 8/10 Iteration: 36500 Avg. Training loss: 3.4912 0.3092 sec/batch
# Epoch 8/10 Iteration: 36600 Avg. Training loss: 3.4492 0.3102 sec/batch
# Epoch 8/10 Iteration: 36700 Avg. Training loss: 3.5174 0.3107 sec/batch
# Epoch 8/10 Iteration: 36800 Avg. Training loss: 3.5259 0.3095 sec/batch
# Epoch 8/10 Iteration: 36900 Avg. Training loss: 3.4897 0.3115 sec/batch
# Epoch 8/10 Iteration: 37000 Avg. Training loss: 3.5408 0.3141 sec/batch
# Nearest to and: staunch, borde, sally, loathing, ashton, bitterly, bitnet, kebir,
# Nearest to history: thrilling, timeline, appreciating, szombathely, predynastic, nonaligned, grapevines, tectonics,
# Nearest to after: tallapoosa, fictive, mismatch, tarentum, hle, comically, cavalier, cherish,
# Nearest to some: yamaha, foreseeable, terraced, multisyllabic, complained, maru, thereof, tima,
# Nearest to state: nationalities, fundraising, nomen, resentment, programmable, bekenstein, inventors, pretended,
# Nearest to th: century, rd, round, miura, palmeri, centuries, bobtail, nd,
# Nearest to six: five, ede, stratovolcano, abensberg, four, three, offset, lazare,
# Nearest to were: plantarum, relic, emmerdale, hastily, porpoises, robles, assigning, dismantling,
# Nearest to primarily: beacons, nyu, choreographies, depicted, precautions, pcb, gunships, plausibly,
# Nearest to universe: bang, temptation, acceleration, spinoza, nucleosynthesis, griechische, big, tractable,
# Nearest to joseph: keller, wilhelm, recreating, redactor, ragnar, philosophiques, triadic, pardey,
# Nearest to assembly: majilis, niemeyer, subunits, deputies, legislative, emissaries, duval, bicameral,
# Nearest to troops: causa, federals, refinery, surrendered, kuroda, shawar, memoirs, ashbury,
# Nearest to channel: criollo, airing, librarianship, fox, orientis, aegeus, multicast, channels,
# Nearest to grand: prix, farces, tiamat, all, vitebsk, italiani, guts, auto,
# Nearest to engineering: bioengineering, engineers, introduced, building, mechanical, disciplines, transplantation, traitorous,
# Epoch 9/10 Iteration: 37100 Avg. Training loss: 3.5186 0.2616 sec/batch
# Epoch 9/10 Iteration: 37200 Avg. Training loss: 3.4954 0.3159 sec/batch
# Epoch 9/10 Iteration: 37300 Avg. Training loss: 3.4880 0.3181 sec/batch
# Epoch 9/10 Iteration: 37400 Avg. Training loss: 3.5254 0.3154 sec/batch
# Epoch 9/10 Iteration: 37500 Avg. Training loss: 3.4308 0.3091 sec/batch
# Epoch 9/10 Iteration: 37600 Avg. Training loss: 3.4726 0.3095 sec/batch
# Epoch 9/10 Iteration: 37700 Avg. Training loss: 3.4304 0.3097 sec/batch
# Epoch 9/10 Iteration: 37800 Avg. Training loss: 3.5073 0.3088 sec/batch
# Epoch 9/10 Iteration: 37900 Avg. Training loss: 3.4768 0.3097 sec/batch
# Epoch 9/10 Iteration: 38000 Avg. Training loss: 3.5166 0.3108 sec/batch
# Nearest to and: staunch, sally, borde, loathing, professing, bitnet, bitterly, ashton,
# Nearest to history: thrilling, timeline, appreciating, szombathely, predynastic, mlb, tectonics, grapevines,
# Nearest to after: fictive, tallapoosa, mismatch, tarentum, cherish, hle, comically, fourth,
# Nearest to some: thereof, terraced, yamaha, foreseeable, maru, complained, tima, multisyllabic,
# Nearest to state: fundraising, nationalities, nomen, resentment, algae, inventors, sponsor, programmable,
# Nearest to th: century, rd, centuries, round, nd, bobtail, palmeri, traditions,
# Nearest to six: ede, stratovolcano, abensberg, five, four, lazare, orangutans, kib,
# Nearest to were: plantarum, relic, porpoises, hastily, robles, lcds, emmerdale, assigning,
# Nearest to primarily: beacons, nyu, choreographies, pcb, precautions, plausibly, depicted, folk,
# Nearest to universe: bang, acceleration, nucleosynthesis, big, tractable, temptation, spinoza, primordial,
# Nearest to joseph: keller, redactor, triadic, wilhelm, recreating, pardey, genesee, philosophiques,
# Nearest to assembly: majilis, niemeyer, legislative, duval, subunits, deputies, emissaries, azathoth,
# Nearest to troops: causa, federals, refinery, surrendered, memoirs, shawar, ashbury, kuroda,
# Nearest to channel: criollo, airing, orientis, librarianship, fox, aegeus, tv, multicast,
# Nearest to grand: prix, farces, tiamat, all, auto, vitebsk, barriers, italiani,
# Nearest to engineering: bioengineering, engineers, building, introduced, mechanical, disciplines, gr, transplantation,
# Epoch 9/10 Iteration: 38100 Avg. Training loss: 3.4859 0.3128 sec/batch
# Epoch 9/10 Iteration: 38200 Avg. Training loss: 3.4132 0.3102 sec/batch
# Epoch 9/10 Iteration: 38300 Avg. Training loss: 3.4599 0.3100 sec/batch
# Epoch 9/10 Iteration: 38400 Avg. Training loss: 3.4335 0.3100 sec/batch
# Epoch 9/10 Iteration: 38500 Avg. Training loss: 3.4495 0.3084 sec/batch
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 3.4714 0.3085 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 3.5094 0.3091 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.4411 0.3092 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.4910 0.3092 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.5150 0.3088 sec/batch
# Nearest to and: staunch, sally, borde, loathing, ashton, bitnet, professing, epidemiological,
# Nearest to history: thrilling, timeline, appreciating, szombathely, predynastic, grapevines, nonaligned, mlb,
# Nearest to after: fictive, mismatch, tallapoosa, cherish, tarentum, fourth, hle, comically,
# Nearest to some: foreseeable, yamaha, thereof, complained, terraced, multisyllabic, ghanaians, maru,
# Nearest to state: fundraising, nationalities, nomen, inventors, programmable, algae, resentment, sponsor,
# Nearest to th: century, rd, nd, bobtail, round, centuries, mascheroni, palmeri,
# Nearest to six: five, ede, stratovolcano, four, seven, abensberg, lazare, bernardi,
# Nearest to were: plantarum, relic, hastily, porpoises, robles, emmerdale, brearley, lcds,
# Nearest to primarily: beacons, nyu, plausibly, pcb, choreographies, folk, precautions, gunships,
# Nearest to universe: bang, big, nucleosynthesis, acceleration, temptation, tractable, spinoza, griechische,
# Nearest to joseph: keller, redactor, pardey, arrivals, triadic, wilhelm, osmotic, stalinism,
# Nearest to assembly: majilis, niemeyer, legislative, subunits, deputies, duval, emissaries, azathoth,
# Nearest to troops: causa, federals, surrendered, refinery, shawar, ashbury, kuroda, surrender,
# Nearest to channel: airing, criollo, tv, fox, librarianship, orientis, aegeus, talk,
# Nearest to grand: prix, tiamat, farces, all, barriers, auto, italiani, vitebsk,
# Nearest to engineering: bioengineering, engineers, building, introduced, disciplines, gr, transplantation, encouragement,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.4633 0.3146 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.4610 0.3102 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.4755 0.3105 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.4962 0.3101 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.4774 0.3098 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.5004 0.3095 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.4917 0.3098 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.4815 0.3103 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.5326 0.3087 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.4835 0.3079 sec/batch
# Nearest to and: staunch, borde, sally, ashton, professing, epidemiological, glycoproteins, varnothing,
# Nearest to history: thrilling, timeline, predynastic, nonaligned, appreciating, reichskammergericht, pejorative, szombathely,
# Nearest to after: fictive, tallapoosa, hle, mismatch, fourth, tarentum, cherish, nonconfirmative,
# Nearest to some: foreseeable, yamaha, terraced, multisyllabic, thereof, tima, complained, ghanaians,
# Nearest to state: nationalities, fundraising, nomen, programmable, inventors, sponsor, algae, resentment,
# Nearest to th: century, rd, centuries, round, bobtail, nd, palmeri, traditions,
# Nearest to six: ede, stratovolcano, five, abensberg, seven, orangutans, four, lazare,
# Nearest to were: plantarum, relic, porpoises, hastily, robles, exactly, brearley, emmerdale,
# Nearest to primarily: beacons, nyu, plausibly, gunships, folk, pcb, choreographies, substituent,
# Nearest to universe: bang, big, nucleosynthesis, acceleration, tractable, temptation, griechische, primordial,
# Nearest to joseph: keller, triadic, pardey, redactor, contemporary, philosophiques, wilhelm, candace,
# Nearest to assembly: majilis, niemeyer, subunits, duval, emissaries, deputies, legislative, azathoth,
# Nearest to troops: causa, federals, surrendered, refinery, memoirs, surrender, riddled, shawar,
# Nearest to channel: criollo, airing, fox, tv, librarianship, orientis, aegeus, follett,
# Nearest to grand: prix, farces, tiamat, all, vitebsk, italiani, barriers, way,
# Nearest to engineering: bioengineering, engineers, introduced, building, disciplines, transplantation, mechanical, gr,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.4873 0.3140 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.4788 0.3115 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.4683 0.3081 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.4440 0.3086 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.5307 0.3076 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.4978 0.3090 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.5892 0.3100 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.5193 0.3102 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.5427 0.3100 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.4433 0.3091 sec/batch
# Nearest to and: staunch, borde, sally, loathing, professing, nanih, ashton, bitterly,
# Nearest to history: thrilling, timeline, predynastic, appreciating, nonaligned, szombathely, grapevines, pejorative,
# Nearest to after: fictive, mismatch, tallapoosa, tarentum, hle, fourth, cherish, comically,
# Nearest to some: yamaha, foreseeable, complained, tima, multisyllabic, terraced, maru, relatives,
# Nearest to state: nationalities, nomen, fundraising, programmable, inventors, sponsor, resentment, secede,
# Nearest to th: century, rd, centuries, bobtail, nd, round, traditions, palmeri,
# Nearest to six: stratovolcano, ede, five, offset, lazare, orangutans, four, abensberg,
# Nearest to were: plantarum, relic, hastily, porpoises, emmerdale, exactly, robles, kashubians,
# Nearest to primarily: beacons, nyu, pcb, gunships, choreographies, plausibly, folk, oddities,
# Nearest to universe: bang, big, nucleosynthesis, tractable, temptation, griechische, acceleration, primordial,
# Nearest to joseph: keller, recreating, stalinism, pardey, redactor, contemporary, philosophiques, flora,
# Nearest to assembly: majilis, niemeyer, subunits, emissaries, legislative, duval, deputies, azathoth,
# Nearest to troops: federals, surrendered, causa, memoirs, refinery, ashbury, surrender, riddled,
# Nearest to channel: criollo, airing, fox, orientis, channels, aegeus, librarianship, tv,
# Nearest to grand: prix, tiamat, farces, all, vitebsk, italiani, posen, contradistinction,
# Nearest to engineering: bioengineering, engineers, introduced, transplantation, building, mechanical, disciplines, occupants,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.4322 0.3140 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.4936 0.3091 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.4316 0.3103 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.5067 0.3096 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.4646 0.3105 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.4842 0.3137 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.5117 0.1759 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.4559 0.3094 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.4536 0.3834 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.4949 0.3165 sec/batch
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-131-b1d3869cd0d6> in <module>()
#      34                 ## From Thushan Ganegedara's implementation
#      35                 # note that this is expensive (~20% slowdown if computed every 500 steps)
# ---> 36                 sim = similarity.eval()
#      37                 for i in range(valid_size):
#      38                     valid_word = int_to_vocab[valid_examples[i]]
#
# /Users/wxp5006/miniconda3/envs/dlnd-tf-lab/lib/python3.5/site-packages/tensorflow/python/framework/ops.py in eval(self, feed_dict, session)
#     579
#     580     """
# --> 581     return _eval_using_default_session(self, feed_dict, self.graph, session)
#     582
#     583
#
# /Users/wxp5006/miniconda3/envs/dlnd-tf-lab/lib/python3.5/site-packages/tensorflow/python/framework/ops.py in _eval_using_default_session(tensors, feed_dict, graph, session)
#    3795                        "the tensor's graph is different from the session's "
#    3796                        "graph.")
# -> 3797   return session.run(tensors, feed_dict)
#    3798
#    3799
#
# /Users/wxp5006/miniconda3/envs/dlnd-tf-lab/lib/python3.5/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     765     try:
#     766       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 767                          run_metadata_ptr)
#     768       if run_metadata:
#     769         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /Users/wxp5006/miniconda3/envs/dlnd-tf-lab/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     963     if final_fetches or final_targets:
#     964       results = self._do_run(handle, final_targets, final_fetches,
# --> 965                              feed_dict_string, options, run_metadata)
#     966     else:
#     967       results = []
#
# /Users/wxp5006/miniconda3/envs/dlnd-tf-lab/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1013     if handle is None:
#    1014       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1015                            target_list, options, run_metadata)
#    1016     else:
#    1017       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /Users/wxp5006/miniconda3/envs/dlnd-tf-lab/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1020   def _do_call(self, fn, *args):
#    1021     try:
# -> 1022       return fn(*args)
#    1023     except errors.OpError as e:
#    1024       message = compat.as_text(e.message)
#
# /Users/wxp5006/miniconda3/envs/dlnd-tf-lab/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1002         return tf_session.TF_Run(session, options,
#    1003                                  feed_dict, fetch_list, target_list,
# -> 1004                                  status, run_metadata)
#    1005
#    1006     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
